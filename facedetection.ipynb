# %% [markdown]
# <a href="https://colab.research.google.com/github/hiteshpujari/Machine-Learning-/blob/master/facedetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get -qq install -y libsm6 libxext6 && pip install -q -U opencv-python

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-63903895-7418-47b3-84af-308ca54318aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63903895-7418-47b3-84af-308ca54318aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hitesh.jpg to hitesh.jpg

# %%
# Load the cascade
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_alt2.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')

# %%
# Read the input image
img = cv2.imread('hitesh.jpg')
plt.imshow(img, cmap='gray')

# %%
# Convert into grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# Detect faces
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-39-60adf95fc900> in <module>()
#       1 # Detect faces
# ----> 2 faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#
# error: OpenCV(4.1.2) /io/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'

# %%
# Display the output
cv2.imshow('img', img)
cv2.waitKey()
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-35-a43ab28ff3a6> in <module>()
#       1 # Display the output
# ----> 2 cv2.imshow('img', img)
#       3 cv2.waitKey()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
