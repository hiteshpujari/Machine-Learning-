# %% [markdown]
# <a href="https://colab.research.google.com/github/hiteshpujari/Machine-Learning-/blob/master/facedetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-083fc2d5-f393-44ac-96e0-1b61321edae4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-083fc2d5-f393-44ac-96e0-1b61321edae4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hitesh.jpg to hitesh.jpg

# %%
# !ls
# Out:
# hitesh.jpg  sample_data

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9468a4c6-dbbe-4823-8479-5333964a3aae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9468a4c6-dbbe-4823-8479-5333964a3aae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving haarcascade_frontalface_default.xml to haarcascade_frontalface_default.xml

# %%
# Load the cascade
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
#eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')

# %%
# Read the input image
img = cv2.imread('hitesh.jpg')
plt.imshow(img, cmap='gray')

# %%
# Convert into grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# Detect faces
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# %%
# draw the face rectangle
for x,y,w,h in faces:
    img = cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0),4)

# %%
,# Display the output
plt.imshow(img, cmap='gray')
